// %% [markdown]
// # Lab 6
//
// Deadline: **Week 8** in your respective lab session

// %% [markdown]
// ### Name:Mohammad Maaz khan
// ### Student ID:230909872

// %% [markdown]
// ***
// <span style="color: red;">You are not required to write anything for this lab sheet except for a simple Java program (e.g. print "Hello World!"). Review each question you want to get marked and ensure you know how to do it. You will be required to do it live when getting it marked by a demonstrator in your allocated lab.
//
// <u style="color: red;">Please have a simple Java program ready before getting assessed!</u></span>

// %% [markdown]
// ***
//
// ## Question 1 [1 mark]

// %% [markdown]
// Write a straightforward Java program, like one that prints out "Hello World!", using only a text editor (no fancy IDEs allowed). Then, explore essential command line (e.g., Terminal on macOS, Command Prompt on Windows) operations:
// * Start by listing the files residing in the current directory, understanding your workspace.
// * Practice navigating through directories, moving deeper into folders and then returning to the surface.
// * Observe the process of compiling your Java program, ensuring it's converted into bytecode.
// * Disassemble the bytecode and explore the bytecode generated by the compiler to understand its underlying structure and operations.
// * Finally, witness your code come to life by running it and seeing the output.

// %% [markdown]
// ***
//
// ## Question 2 [1 mark]

// %% [markdown]
// Create a new empty GitHub repository. Ensure you have a GitHub account and are logged in. Using the command line, clone your newly created GitHub repository to create a local Git repository on your computer.

// %% [markdown]
// ***
// ## Question 3 [1 mark]

// %% [markdown]
// Manually move the simple Java source code you created earlier in Question 1 to your local repository. Now, using the command line:
// 1. Add the source code to the staging area
// 2. Commit the changes
// 3. Push the committed changes to GitHub
//
// Lastly, head over to the GitHub website to check out the commit history and see the changes you've made.
//
// **Hint:** Please note that you may need to authenticate with GitHub to push your changes. If you encounter any authentication issues, you'll need to use an access token.  If you're not sure how to generate or use one, check out GitHub's documentation for guidance or reach out if you need help.

// %% [markdown]
// ***

// %% [markdown]
// ## Question 4 [1 mark]

// %% [markdown]
// Perform the following tasks using the command line:
// 1. Check which branch you are currently on
// 2. Create a new branch
// 3. Switch to the newly created branch
// 4. Manually create a copy of your source code (created in Question 1) within your local Git repository directory
// 5. Push the changes to the remote repository
// 6. Review and confirm the changes on the GitHub website
// 6. Merge the changes from your new branch into the main branch

// %% [markdown]
// ***

// %% [markdown]
// ## Question 5 [1 mark]

// %% [markdown]
// 1. Begin by creating a new branch from the command line and switching to it.
// 2. Introduce conflicting changes to a Java file in both the new branch and the main branch.
// 3. Proceed to push the changes to your new branch and merge it with the main branch using Git commands.
// 4. Then, on GitHub, initiate a pull request and navigate to resolve any resulting merge conflicts.
